# %% [markdown]
# ## Importing the required packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.svm import SVR
from sklearn.metrics import r2_score

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
import keras.backend as K
# Out:
# Using TensorFlow backend.
# C:\Users\Ram\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Ram\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Ram\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Ram\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Ram\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Ram\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\Ram\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Ram\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Ram\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Ram\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Ram\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Ram\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# ## Getting the NY times data directly from the Github repo

# %%
url = 'https://raw.githubusercontent.com/nytimes/covid-19-data/master/us.csv'
us = pd.read_csv(url)

# %%
(us.head(5))
# Out:
#          date  cases  deaths
# 0  2020-01-21      1       0
# 1  2020-01-22      1       0
# 2  2020-01-23      1       0
# 3  2020-01-24      2       0
# 4  2020-01-25      3       0

# %%
url = 'https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-states.csv'
us_states = pd.read_csv(url)

# %%
us_states.head(5)
# Out:
#          date       state  fips  cases  deaths
# 0  2020-01-21  Washington    53      1       0
# 1  2020-01-22  Washington    53      1       0
# 2  2020-01-23  Washington    53      1       0
# 3  2020-01-24    Illinois    17      1       0
# 4  2020-01-24  Washington    53      1       0

# %%
url = 'https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv'
us_counties = pd.read_csv(url)

# %%
us_counties.head(5)
# Out:
#          date     county       state     fips  cases  deaths
# 0  2020-01-21  Snohomish  Washington  53061.0      1       0
# 1  2020-01-22  Snohomish  Washington  53061.0      1       0
# 2  2020-01-23  Snohomish  Washington  53061.0      1       0
# 3  2020-01-24       Cook    Illinois  17031.0      1       0
# 4  2020-01-24  Snohomish  Washington  53061.0      1       0

# %%
us['date'] = pd.to_datetime(us['date'])

# %%
us.dtypes
# Out:
# date      datetime64[ns]
# cases              int64
# deaths             int64
# dtype: object

# %%
us.head()
# Out:
#         date  cases  deaths
# 0 2020-01-21      1       0
# 1 2020-01-22      1       0
# 2 2020-01-23      1       0
# 3 2020-01-24      2       0
# 4 2020-01-25      3       0

# %%
us.plot(x = "date", y = ["cases",'deaths'])

# %% [markdown]
# ## Testing the data by moving the Date to Index

# %%
df_idx = us.set_index(["date"], drop=True)
df_idx.head(5)
# Out:
#             cases  deaths
# date
# 2020-01-21      1       0
# 2020-01-22      1       0
# 2020-01-23      1       0
# 2020-01-24      2       0
# 2020-01-25      3       0

# %%
df_idx = df_idx.sort_index(axis=1, ascending=True)
df_idx = df_idx.iloc[::-1]

# %%
df_idx.head(5)
# Out:
#               cases  deaths
# date
# 2020-09-08  6345771  189538
# 2020-09-07  6317221  189076
# 2020-09-06  6292054  188815
# 2020-09-05  6260993  188409
# 2020-09-04  6218913  187698

# %% [markdown]
# ## Splitting the Data into Train and Test to start the Model Creation

# %%
n = len(us)
train_df = us[0:int(n*0.8)]
test_df = us[int(n*0.8):]

# %%
train_df.head()
# Out:
#         date  cases  deaths
# 0 2020-01-21      1       0
# 1 2020-01-22      1       0
# 2 2020-01-23      1       0
# 3 2020-01-24      2       0
# 4 2020-01-25      3       0

# %%
test_df.head()
# Out:
#           date    cases  deaths
# 185 2020-07-24  4123413  145429
# 186 2020-07-25  4190189  146312
# 187 2020-07-26  4244406  146752
# 188 2020-07-27  4303587  148448
# 189 2020-07-28  4366697  149775

# %%
train_df.dtypes
# Out:
# date      datetime64[ns]
# cases              int64
# deaths             int64
# dtype: object

# %%
test_df.dtypes
# Out:
# date      datetime64[ns]
# cases              int64
# deaths             int64
# dtype: object

# %%
ax = train_df.plot(figsize=(10,12), x = 'date')
test_df.plot(ax=ax, x = 'date')
plt.show()

# %%
X_train = pd.DataFrame(train_df[['date','cases']])
y_train = pd.DataFrame(train_df[['deaths']])

# %%
X_train.head(10)
# Out:
#         date  cases
# 0 2020-01-21      1
# 1 2020-01-22      1
# 2 2020-01-23      1
# 3 2020-01-24      2
# 4 2020-01-25      3
# 5 2020-01-26      5
# 6 2020-01-27      5
# 7 2020-01-28      5
# 8 2020-01-29      5
# 9 2020-01-30      6

# %%
X_test = pd.DataFrame(test_df[['date','cases']])
y_test = pd.DataFrame(test_df[['deaths']])

# %%
X_test.head(10)
# Out:
#           date    cases
# 185 2020-07-24  4123413
# 186 2020-07-25  4190189
# 187 2020-07-26  4244406
# 188 2020-07-27  4303587
# 189 2020-07-28  4366697
# 190 2020-07-29  4433312
# 191 2020-07-30  4502423
# 192 2020-07-31  4571482
# 193 2020-08-01  4628303
# 194 2020-08-02  4679096

# %%
X_train['year'] = X_train['date'].dt.year 
X_train['month'] = X_train['date'].dt.month 
X_train['day'] = X_train['date'].dt.day

# %%
X_train.head()
# Out:
#         date  cases  year  month  day
# 0 2020-01-21      1  2020      1   21
# 1 2020-01-22      1  2020      1   22
# 2 2020-01-23      1  2020      1   23
# 3 2020-01-24      2  2020      1   24
# 4 2020-01-25      3  2020      1   25

# %%
X_test['year'] = X_test['date'].dt.year 
X_test['month'] = X_test['date'].dt.month 
X_test['day'] = X_test['date'].dt.day

# %%
X_test
# Out:
#           date    cases  year  month  day
# 185 2020-07-24  4123413  2020      7   24
# 186 2020-07-25  4190189  2020      7   25
# 187 2020-07-26  4244406  2020      7   26
# 188 2020-07-27  4303587  2020      7   27
# 189 2020-07-28  4366697  2020      7   28
# 190 2020-07-29  4433312  2020      7   29
# 191 2020-07-30  4502423  2020      7   30
# 192 2020-07-31  4571482  2020      7   31
# 193 2020-08-01  4628303  2020      8    1
# 194 2020-08-02  4679096  2020      8    2
# 195 2020-08-03  4726579  2020      8    3
# 196 2020-08-04  4780116  2020      8    4
# 197 2020-08-05  4833837  2020      8    5
# 198 2020-08-06  4891532  2020      8    6
# 199 2020-08-07  4952682  2020      8    7
# 200 2020-08-08  5007922  2020      8    8
# 201 2020-08-09  5056410  2020      8    9
# 202 2020-08-10  5103575  2020      8   10
# 203 2020-08-11  5156920  2020      8   11
# 204 2020-08-12  5211203  2020      8   12
# 205 2020-08-13  5265260  2020      8   13
# 206 2020-08-14  5324737  2020      8   14
# 207 2020-08-15  5375486  2020      8   15
# 208 2020-08-16  5417629  2020      8   16
# 209 2020-08-17  5455136  2020      8   17
# 210 2020-08-18  5498362  2020      8   18
# 211 2020-08-19  5541376  2020      8   19
# 212 2020-08-20  5587401  2020      8   20
# 213 2020-08-21  5636428  2020      8   21
# 214 2020-08-22  5681459  2020      8   22
# 215 2020-08-23  5713799  2020      8   23
# 216 2020-08-24  5754178  2020      8   24
# 217 2020-08-25  5793346  2020      8   25
# 218 2020-08-26  5838125  2020      8   26
# 219 2020-08-27  5883729  2020      8   27
# 220 2020-08-28  5930285  2020      8   28
# 221 2020-08-29  5974924  2020      8   29
# 222 2020-08-30  6008376  2020      8   30
# 223 2020-08-31  6044815  2020      8   31
# 224 2020-09-01  6088842  2020      9    1
# 225 2020-09-02  6121842  2020      9    2
# 226 2020-09-03  6167443  2020      9    3
# 227 2020-09-04  6218913  2020      9    4
# 228 2020-09-05  6260993  2020      9    5
# 229 2020-09-06  6292054  2020      9    6
# 230 2020-09-07  6317221  2020      9    7
# 231 2020-09-08  6345771  2020      9    8

# %% [markdown]
# ## Performing Correlation analysis on the Train and Test Data to see if theres any underlying patterns

# %%
X_train.corr()
# Out:
#           cases  year     month       day
# cases  1.000000   NaN  0.934237 -0.023453
# year        NaN   NaN       NaN       NaN
# month  0.934237   NaN  1.000000 -0.196380
# day   -0.023453   NaN -0.196380  1.000000

# %%
X_train.corr(method='spearman')
# Out:
#           cases  year     month       day
# cases  1.000000   NaN  0.988008 -0.038833
# year        NaN   NaN       NaN       NaN
# month  0.988008   NaN  1.000000 -0.186729
# day   -0.038833   NaN -0.186729  1.000000

# %%
X_train.corr(method='kendall')
# Out:
#           cases  year     month       day
# cases  1.000000   NaN  0.924174  0.022782
# year        NaN   1.0       NaN       NaN
# month  0.924174   NaN  1.000000 -0.135259
# day    0.022782   NaN -0.135259  1.000000

# %%
X_test.corr()
# Out:
#           cases  year     month       day
# cases  1.000000   NaN  0.839995 -0.167654
# year        NaN   NaN       NaN       NaN
# month  0.839995   NaN  1.000000 -0.672411
# day   -0.167654   NaN -0.672411  1.000000

# %%
X_test.corr(method='spearman')
# Out:
#           cases  year     month       day
# cases  1.000000   NaN  0.838758 -0.158260
# year        NaN   NaN       NaN       NaN
# month  0.838758   NaN  1.000000 -0.667014
# day   -0.158260   NaN -0.667014  1.000000

# %%
X_test.corr(method='kendall')
# Out:
#           cases  year     month       day
# cases  1.000000   NaN  0.719749  0.082947
# year        NaN   1.0       NaN       NaN
# month  0.719749   NaN  1.000000 -0.559390
# day    0.082947   NaN -0.559390  1.000000

# %% [markdown]
# ## Creating a Base model for comparison with Support Vector Regression (SVR)

# %%
X_train_2 = X_train.drop('date',1)
X_test_2 = X_test.drop('date',1)

# %%
y_test
# Out:
#      deaths
# 185  145429
# 186  146312
# 187  146752
# 188  148448
# 189  149775
# 190  151170
# 191  152431
# 192  153860
# 193  154915
# 194  155335
# 195  155943
# 196  157299
# 197  158551
# 198  159626
# 199  160982
# 200  161948
# 201  162487
# 202  163024
# 203  164475
# 204  165953
# 205  167166
# 206  168342
# 207  169401
# 208  169915
# 209  170450
# 210  171799
# 211  173094
# 212  174137
# 213  175298
# 214  176248
# 215  176694
# 216  177198
# 217  178411
# 218  179604
# 219  180730
# 220  181740
# 221  182611
# 222  182985
# 223  183473
# 224  184564
# 225  185640
# 226  186718
# 227  187698
# 228  188409
# 229  188815
# 230  189076
# 231  189538

# %%
from sklearn.svm import SVR
regressor = SVR(kernel='sigmoid', gamma='scale')

# %%
regressor.fit(X_train_2, y_train)
y_pred = regressor.predict(X_test_2)
# Out:
# C:\Users\Ram\anaconda3\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_test
# Out:
#      deaths
# 185  145429
# 186  146312
# 187  146752
# 188  148448
# 189  149775
# 190  151170
# 191  152431
# 192  153860
# 193  154915
# 194  155335
# 195  155943
# 196  157299
# 197  158551
# 198  159626
# 199  160982
# 200  161948
# 201  162487
# 202  163024
# 203  164475
# 204  165953
# 205  167166
# 206  168342
# 207  169401
# 208  169915
# 209  170450
# 210  171799
# 211  173094
# 212  174137
# 213  175298
# 214  176248
# 215  176694
# 216  177198
# 217  178411
# 218  179604
# 219  180730
# 220  181740
# 221  182611
# 222  182985
# 223  183473
# 224  184564
# 225  185640
# 226  186718
# 227  187698
# 228  188409
# 229  188815
# 230  189076
# 231  189538

# %%
y_pred
# Out:
# array([47081.35206915, 47081.25237964, 47081.17053564, 47081.08043272,
#        47080.98363214, 47080.88083483, 47080.77370046, 47080.66633208,
#        47080.57787082, 47080.49877605, 47080.42487068, 47080.34163613,
#        47080.2582684 , 47080.16896234, 47080.07462987, 47079.98975018,
#        47079.91554268, 47079.84365268, 47079.7627189 , 47079.68080067,
#        47079.59969091, 47079.5110176 , 47079.4358499 , 47079.37378712,
#        47079.31883249, 47079.2558342 , 47079.1935093 , 47079.12723228,
#        47079.05710793, 47078.99313856, 47078.94746055, 47078.89073998,
#        47078.83605453, 47078.7739417 , 47078.71113389, 47078.64748607,
#        47078.58690871, 47078.54180251, 47078.49295221, 47078.43432483,
#        47078.39066554, 47078.33073647, 47078.26365442, 47078.20925196,
#        47078.16934984, 47078.13717785, 47078.10085283])

# %%
plt.plot(y_test)
plt.plot(y_pred)

# %%
def adj_r2_score(r2, n, k):
    return 1-((1-r2)*((n-1)/(n-k-1)))

r2_test = r2_score(y_test, y_pred)
print("R-squared is: %f"%r2_test)
# Out:
# R-squared is: -83.185410

# %%
n = len(us)
train_df = us[0:int(n*0.8)]
test_df = us[int(n*0.8):]

# %%
train_df['year'] = train_df['date'].dt.year 
train_df['month'] = train_df['date'].dt.month 
train_df['day'] = train_df['date'].dt.day
# Out:
# C:\Users\Ram\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Ram\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Ram\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
test_df['year'] = test_df['date'].dt.year 
test_df['month'] = test_df['date'].dt.month 
test_df['day'] = test_df['date'].dt.day
# Out:
# C:\Users\Ram\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Ram\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Ram\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
test_df
# Out:
#           date    cases  deaths  year  month  day
# 185 2020-07-24  4123413  145429  2020      7   24
# 186 2020-07-25  4190189  146312  2020      7   25
# 187 2020-07-26  4244406  146752  2020      7   26
# 188 2020-07-27  4303587  148448  2020      7   27
# 189 2020-07-28  4366697  149775  2020      7   28
# 190 2020-07-29  4433312  151170  2020      7   29
# 191 2020-07-30  4502423  152431  2020      7   30
# 192 2020-07-31  4571482  153860  2020      7   31
# 193 2020-08-01  4628303  154915  2020      8    1
# 194 2020-08-02  4679096  155335  2020      8    2
# 195 2020-08-03  4726579  155943  2020      8    3
# 196 2020-08-04  4780116  157299  2020      8    4
# 197 2020-08-05  4833837  158551  2020      8    5
# 198 2020-08-06  4891532  159626  2020      8    6
# 199 2020-08-07  4952682  160982  2020      8    7
# 200 2020-08-08  5007922  161948  2020      8    8
# 201 2020-08-09  5056410  162487  2020      8    9
# 202 2020-08-10  5103575  163024  2020      8   10
# 203 2020-08-11  5156920  164475  2020      8   11
# 204 2020-08-12  5211203  165953  2020      8   12
# 205 2020-08-13  5265260  167166  2020      8   13
# 206 2020-08-14  5324737  168342  2020      8   14
# 207 2020-08-15  5375486  169401  2020      8   15
# 208 2020-08-16  5417629  169915  2020      8   16
# 209 2020-08-17  5455136  170450  2020      8   17
# 210 2020-08-18  5498362  171799  2020      8   18
# 211 2020-08-19  5541376  173094  2020      8   19
# 212 2020-08-20  5587401  174137  2020      8   20
# 213 2020-08-21  5636428  175298  2020      8   21
# 214 2020-08-22  5681459  176248  2020      8   22
# 215 2020-08-23  5713799  176694  2020      8   23
# 216 2020-08-24  5754178  177198  2020      8   24
# 217 2020-08-25  5793346  178411  2020      8   25
# 218 2020-08-26  5838125  179604  2020      8   26
# 219 2020-08-27  5883729  180730  2020      8   27
# 220 2020-08-28  5930285  181740  2020      8   28
# 221 2020-08-29  5974924  182611  2020      8   29
# 222 2020-08-30  6008376  182985  2020      8   30
# 223 2020-08-31  6044815  183473  2020      8   31
# 224 2020-09-01  6088842  184564  2020      9    1
# 225 2020-09-02  6121842  185640  2020      9    2
# 226 2020-09-03  6167443  186718  2020      9    3
# 227 2020-09-04  6218913  187698  2020      9    4
# 228 2020-09-05  6260993  188409  2020      9    5
# 229 2020-09-06  6292054  188815  2020      9    6
# 230 2020-09-07  6317221  189076  2020      9    7
# 231 2020-09-08  6345771  189538  2020      9    8

# %%
del train_df['date']
del test_df['date']

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
train_sc = sc.fit_transform(train_df)
test_sc = sc.transform(test_df)

# %%
y_train = train_df[['deaths']]
X_train = train_df[['year','month','day','cases']]

y_test = test_df[['deaths']]
X_test = test_df[['year','month','day','cases']]

# %%
from sklearn.svm import SVR
regressor = SVR(kernel='rbf')

# %%
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
# Out:
# C:\Users\Ram\anaconda3\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
plt.plot(y_test)
plt.plot(y_pred)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression().fit(X_train, y_train)

# %%
reg.score(X_train, y_train)
# Out:
# 0.9564924265498697

# %%
y_pred = reg.predict(X_test)

# %%
y_pred = np.round(y_pred)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import explained_variance_score
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# -12.958733793833332

# %%
plt.plot(y_test)
plt.plot(y_pred)

# %%
import statsmodels.api as sm

# %%
model = sm.OLS(y_train, X_train)

# %%
results = model.fit()

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 deaths   R-squared:                       0.956
# Model:                            OLS   Adj. R-squared:                  0.956
# Method:                 Least Squares   F-statistic:                     1326.
# Date:                Wed, 09 Sep 2020   Prob (F-statistic):          6.50e-123
# Time:                        16:06:52   Log-Likelihood:                -1988.0
# No. Observations:                 185   AIC:                             3984.
# Df Residuals:                     181   BIC:                             3997.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# year         -15.7898      2.528     -6.247      0.000     -20.777     -10.802
# month       1.177e+04   1495.761      7.867      0.000    8815.938    1.47e+04
# day          428.7019    109.688      3.908      0.000     212.270     645.134
# cases          0.0279      0.002     12.388      0.000       0.023       0.032
# ==============================================================================
# Omnibus:                       19.403   Durbin-Watson:                   0.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               10.756
# Skew:                          -0.424   Prob(JB):                      0.00462
# Kurtosis:                       2.178   Cond. No.                     2.91e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.91e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
y_pred = results.predict(X_test)

# %%
y_pred
# Out:
# 185    175815.991669
# 186    178107.875796
# 187    180049.339020
# 188    182129.307648
# 189    184318.903134
# 190    186606.295043
# 191    188963.330280
# 192    191318.914615
# 193    191810.586439
# 194    193656.513301
# 195    195410.084627
# 196    197332.574509
# 197    199260.198354
# 198    201298.704647
# 199    203433.612263
# 200    205403.619208
# 201    207185.232018
# 202    208929.930516
# 203    210847.063218
# 204    212790.367973
# 205    214727.366882
# 206    216815.594494
# 207    218660.293670
# 208    220264.868450
# 209    221740.089675
# 210    223374.882294
# 211    225003.759694
# 212    226716.649941
# 213    228513.301916
# 214    230198.457599
# 215    231529.509320
# 216    233084.865017
# 217    234606.431422
# 218    236284.555808
# 219    237985.699323
# 220    239713.405519
# 221    241387.623628
# 222    242749.702345
# 223    244195.124261
# 224    244329.818218
# 225    245679.285243
# 226    247380.345052
# 227    249245.161552
# 228    250847.978507
# 229    252143.343603
# 230    253274.254458
# 231    254499.557694
# dtype: float64

# %%
r2_score(y_test, y_pred)
# Out:
# -12.958727547590648
